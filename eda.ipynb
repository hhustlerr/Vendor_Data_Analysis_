# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from ingest_db import ingest_db

# %%
engine = create_engine('postgresql://postgres:password@localhost/inventory')

# %%
# query to read table_names
tables = pd.read_sql("select table_name from information_schema.tables where table_schema = 'public';", engine)
tables
# Out:
#         table_name
# 0    end_inventory
# 1            sales
# 2   vendor_invoice
# 3  begin_inventory
# 4        purchases
# 5  purchase_prices
# 6               df
# 7      final_table

# %%
for table in tables['table_name']:
    count = pd.read_sql(f"select count(*) as count from {table}", engine)['count'].values[0]
    print(table,'--', count)
    display( pd.read_sql(f"select * from {table} limit 5", engine))  # redaing top 5 data of every table
# Out:
# end_inventory -- 224489
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 2  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 3  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
# 4  1_HARDERSFIELD_75      1  HARDERSFIELD     75    Three Olives Tomato Vodka
#
#     Size  onHand  Price     endDate
# 0  750mL      11  12.99  2024-12-31
# 1  750mL       7  36.99  2024-12-31
# 2  750mL       7  38.99  2024-12-31
# 3  750mL       4  34.99  2024-12-31
# 4  750mL       7  14.99  2024-12-31
# sales -- 12825363
#            InventoryId  Store  Brand                 Description        Size  \
# 0  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# 1  1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses       750mL
# ...

# %%
purchases = pd.read_sql('select * from purchases where "VendorNumber" = 4466', engine)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187      31_HORNSEY_5255     31   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2188   67_EANVERNESS_3140     67   3140      TGI Fridays Orange Dream  1.75L
# 2189    73_DONCASTER_5255     73   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2190    34_PITMERDEN_5255     34   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2191      54_GUTHRAM_5215     54   5215  TGI Fridays Long Island Iced  1.75L
#
# ...

# %%
vendor_invoice = pd.read_sql('select * from vendor_invoice where "VendorNumber" = 4466', engine)
vendor_invoice.count()
# Out:
# VendorNumber    55
# VendorName      55
# InvoiceDate     55
# PONumber        55
# PODate          55
# PayDate         55
# Quantity        55
# Dollars         55
# Freight         55
# Approval         0
# dtype: int64

# %%
purchase_prices = pd.read_sql('select * from purchase_prices where "VendorNumber" = 4466', engine)
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
sales = pd.read_sql('select * from sales where "VendorNo" = 4466', engine)
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9449     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     8_ALNERWICK_5255      8   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases.groupby(['Brand', 'PurchasePrice'])[['Quantity', 'Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
freight_summary = pd.read_sql('select "VendorNumber", sum("Freight") as freightCost from vendor_invoice group by "VendorNumber"', engine)
freight_summary
# Out:
#      VendorNumber  freightcost
# 0            7255       648.71
# 1            1439         0.27
# 2            9751        24.53
# 3            6830       360.29
# 4            1587      6070.09
# ..            ...          ...
# 121          9625      1933.19
# 122          7154       432.37
# 123          1392     79528.99
# 124          1189       609.39
# 125         90017        80.03
#
# [126 rows x 2 columns]

# %%
purchases.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3    38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4  59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
#
#    VendorNumber                   VendorName  PONumber      PODate  \
# 0          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 1          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
# 4          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
#
#   ReceivingDate InvoiceDate     PayDate  PurchasePrice  Quantity  Dollars  \
# ...

# %%
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
pd.read_sql("""select 
p."VendorNumber", 
p."VendorName", 
p."Brand", 
p."PurchasePrice", 
pp."Volume",
pp."Price" as "ActualPrice",
sum(p."Quantity") as "TotalPurchaseQuantity", 
sum(p."Dollars") as "TotalPuhchaseDollars" 
from purchases p
join purchase_prices pp 
on p."Brand" = pp."Brand" 
where p."PurchasePrice" > 0
group by
   p."VendorNumber", 
   p."VendorName", 
   p."Brand",
   p."PurchasePrice", 
   pp."Volume",
   pp."Price" 
order by "TotalPuhchaseDollars" """, engine)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql(""" select 
   "VendorNo", 
   "Brand", 
   sum("SalesDollars") as "TotalSalesDollars",
   sum("SalesPrice") as "TotalSalesPrice",
   "Volume",
   sum("SalesQuantity") as "TotalSalesQuantity",
   sum("ExciseTax") as "TotalExciseTax"
    from sales
   where "SalesPrice" > 0
   group by 
   "VendorNo", 
   "Brand", 
   "SalesPrice",
   "Volume"

   order by "TotalSalesDollars" """, engine)
# Out:
#        VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  Volume  \
# 0          8004   5287               0.98             0.98    50.0
# 1          9206   2773               0.99             0.99    50.0
# 2         10050   3623               1.98             1.98    50.0
# 3          3924   9123               1.98             0.99    50.0
# 4          3252   3933               1.98             0.99    50.0
# ...         ...    ...                ...              ...     ...
# 19955      3960   4261         1949896.85        192058.46  1750.0
# 19956      4425   3405         2421692.50        242349.19  1750.0
# 19957     17035   8068         2479416.48        194567.67  1750.0
# 19958      3960   3545         2488690.16        263552.12  1750.0
# 19959      1128   1233         2857178.43        286498.12  1750.0
#
#        TotalSalesQuantity  TotalExciseTax
# 0                     2.0            0.10
# 1                     1.0            0.05
# ...

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
pd.read_sql("""select 
      "VendorNumber",
      sum("Freight") as "FreightCost"
      from vendor_invoice
      group by "VendorNumber" """, engine)
# Out:
#      VendorNumber  FreightCost
# 0            7255       648.71
# 1            1439         0.27
# 2            9751        24.53
# 3            6830       360.29
# 4            1587      6070.09
# ..            ...          ...
# 121          9625      1933.19
# 122          7154       432.37
# 123          1392     79528.99
# 124          1189       609.39
# 125         90017        80.03
#
# [126 rows x 2 columns]

# %%
# now we will join all three tables: vendor_invoice, sales, purchase_prices

final_table = pd.read_sql(""" with freight_summary as (
  select
     "VendorNumber", 
     sum("Freight") as "freightCost" 
     from vendor_invoice 
     group by "VendorNumber"
),
Purchase_summary as (
 select 
     p."VendorNumber", 
     p."VendorName", 
     p."Brand", 
     pp."Description",
     p."PurchasePrice", 
     pp."Volume",
     pp."Price" as "ActualPrice",
     sum(p."Quantity") as "TotalPurchaseQuantity", 
     sum(p."Dollars") as "TotalPuhchaseDollars" 
     from purchases p
     join purchase_prices pp 
     on p."Brand" = pp."Brand" 
     where p."PurchasePrice" > 0
     group by
       p."VendorNumber", 
       p."VendorName", 
       p."Brand",
       pp."Description",
       p."PurchasePrice", 
       pp."Volume",
       pp."Price"  
),
sales_summary as (
  select 
     "VendorNo", 
     "Brand", 
   sum("SalesDollars") as "TotalSalesDollars",
   sum("SalesPrice") as "TotalSalesPrice",
   sum("SalesQuantity") as "TotalSalesQuantity",
   sum("ExciseTax") as "TotalExciseTax"
    from sales
   group by 
   "VendorNo", 
   "Brand"
)

select 
     ps."VendorNumber",
     ps."VendorName",
     ps."Brand",
     ps."Description",
     ps."PurchasePrice",
     ps."ActualPrice",
     ps."Volume",
     ps."TotalPurchaseQuantity",
     ps."TotalPuhchaseDollars",
     ss."TotalSalesQuantity",
     ss."TotalSalesDollars",
     ss."TotalExciseTax",
     fs."freightCost" 
From Purchase_summary ps
left join sales_summary ss
     on ps."VendorNumber" = ss."VendorNo"
     and ps."Brand" = ss."Brand"
left join freight_summary fs
     on ps."VendorNumber" = fs."VendorNumber"
order by ps."TotalPuhchaseDollars" desc """, engine)

# %%
final_table
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99   1750
# 1            Tito's Handmade Vodka          23.19        28.99   1750
# 2                 Absolut 80 Proof          18.24        24.99   1750
# ...

# %%
final_table.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                    object
# TotalPurchaseQuantity    float64
# TotalPuhchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalExciseTax           float64
# freightCost              float64
# dtype: object

# %%
final_table.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPuhchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalExciseTax           178
# freightCost                0
# dtype: int64

# %%
final_table.head()
# Out:
#    VendorNumber                   VendorName  Brand              Description  \
# 0          1128  BROWN-FORMAN CORP             1233  Jack Daniels No 7 Black
# 1          4425        MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035  PERNOD RICARD USA             8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC      4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC      3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99   1750               145080.0
# 1          23.19        28.99   1750               164038.0
# 2          18.24        24.99   1750               187407.0
# 3          16.17        22.99   1750               201682.0
# 4          21.89        29.99   1750               138109.0
#
#    TotalPuhchaseDollars  TotalSalesQuantity  TotalSalesDollars  \
# 0            3811251.60            142049.0         5101919.51
# ...

# %%
final_table['VendorName'] = final_table['VendorName'].str.strip()

# %%
final_table['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP', 'MARTIGNETTI COMPANIES', 'PERNOD RICARD USA',
#        'DIAGEO NORTH AMERICA INC', 'BACARDI USA INC',
#        'JIM BEAM BRANDS COMPANY', 'MAJESTIC FINE WINES',
#        'ULTRA BEVERAGE COMPANY LLP', 'STOLI GROUP,(USA) LLC',
#        'PROXIMO SPIRITS INC.', 'MOET HENNESSY USA INC', 'CAMPARI AMERICA',
#        'SAZERAC CO INC', 'CONSTELLATION BRANDS INC', 'M S WALKER INC',
#        'SAZERAC NORTH AMERICA INC.', 'PALM BAY INTERNATIONAL INC',
#        'REMY COINTREAU USA INC', 'SIDNEY FRANK IMPORTING CO',
#        'E & J GALLO WINERY', 'WILLIAM GRANT & SONS INC',
#        'HEAVEN HILL DISTILLERIES', 'DISARONNO INTERNATIONAL LLC',
#        'EDRINGTON AMERICAS', 'CASTLE BRANDS CORP.',
#        'SOUTHERN WINE & SPIRITS NE', 'STE MICHELLE WINE ESTATES',
#        'TRINCHERO FAMILY ESTATES', 'MHW LTD', 'WINE GROUP INC',
#        'PERFECTA WINES', 'LUXCO INC', 'TREASURY WINE ESTATES',
#        'DIAGEO CHATEAU ESTATE WINES', 'SHAW ROSS INT L IMP LTD',
# ...

# %%
final_table['GrossProfit'] = final_table['TotalSalesDollars'] - final_table['TotalPuhchaseDollars']
final_table['GrossProfit'].min()
# Out:
# -52002.78000000002

# %%
final_table['ProfitMargin'] = (final_table['GrossProfit'] - final_table['TotalSalesDollars'])*100
final_table['ProfitMargin']
# Out:
# 0       -3.811252e+08
# 1       -3.804041e+08
# 2       -3.418304e+08
# 3       -3.261198e+08
# 4       -3.023206e+08
#              ...
# 10687   -2.640000e+02
# 10688   -2.340000e+02
# 10689   -1.480000e+02
# 10690   -1.470000e+02
# 10691   -7.100000e+01
# Name: ProfitMargin, Length: 10692, dtype: float64

# %%
final_table['StockTurnover'] = final_table['TotalSalesQuantity'] / final_table['TotalPurchaseQuantity']
final_table['StockTurnover']
# Out:
# 0         0.979108
# 1         0.976890
# 2         0.998575
# 3         0.993703
# 4         0.983556
#            ...
# 10687     2.500000
# 10688    22.333333
# 10689     1.000000
# 10690    72.000000
# 10691    86.000000
# Name: StockTurnover, Length: 10692, dtype: float64

# %%
final_table['SalesToPurchaseRatio'] = final_table['TotalSalesDollars'] / final_table['TotalPuhchaseDollars']
final_table['SalesToPurchaseRatio']
# Out:
# 0          1.338647
# 1          1.266830
# 2          1.327594
# 3          1.372493
# 4          1.396897
#             ...
# 10687      6.041667
# 10688     28.059829
# 10689      1.337838
# 10690     97.469388
# 10691    119.915493
# Name: SalesToPurchaseRatio, Length: 10692, dtype: float64

# %%
final_table.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'ActualPrice', 'Volume', 'TotalPurchaseQuantity',
#        'TotalPuhchaseDollars', 'TotalSalesQuantity', 'TotalSalesDollars',
#        'TotalExciseTax', 'freightCost', 'GrossProfit', 'ProfitMargin',
#        'StockTurnover', 'SalesToPurchaseRatio'],
#       dtype='object')

# %%
# in companies we save the table in sql by this way(not by to_sql method although it's correct but not professional)
# conn = psycopg2.connect(
#     host = "localhost",
#     port = "5432",
#     database = "inventory",
#     user = "postgres",
#     password = "password"
# )

# cursor = conn.cursor()

# MUST KNOW:
# In Pandas DataFrame: You give actual values
# In PostgreSQL: You define column types (VARCHAR, DECIMAL, INT, etc.)


df = pd.DataFrame([
    {   "VendorName": "ABC Ltd",
        "VendorNumber": 1,
        "Brand": 100,
        "Volume": 50,
        "Description": "ABC Ltd",
        "ActualPrice": 500.00,
        "PurchasePrice": 450.00,
        "TotalPurchaseQuantity": 100,
        "TotalPurchaseDollars": 45000.00,
        "TotalSalesDollar": 50000.00,
        "TotalSalesQuantity": 100,
        "TotalExciseTax": 2000.00,
        "freightCost": 500.00,
        "GrossProfit": 5000.00,
        "ProfitMargin": 10.00,
        "StockTurnover": 5.00,
        "SalesToPurchaseRatio": 1.1
      # primary key: ("VendorNumber", "Brand")  >> we can set a primary key while creating a table in postgresql not in pandas dataframe 
    }
]
)

df.to_sql("df", engine, if_exists = 'replace', index = False)
# Out:
# 1

# %%
df.columns
# Out:
# Index(['VendorName', 'VendorNumber', 'Brand', 'Volume', 'Description',
#        'ActualPrice', 'PurchasePrice', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalSalesDollar', 'TotalSalesQuantity',
#        'TotalExciseTax', 'freightCost', 'GrossProfit', 'ProfitMargin',
#        'StockTurnover', 'SalesToPurchaseRatio'],
#       dtype='object')

# %%
pd.read_sql("select * from df", engine)
# Out:
#   VendorName  VendorNumber  Brand  Volume Description  ActualPrice  \
# 0    ABC Ltd             1    100      50     ABC Ltd        500.0
#
#    PurchasePrice  TotalPurchaseQuantity  TotalPurchaseDollars  \
# 0          450.0                    100               45000.0
#
#    TotalSalesDollar  TotalSalesQuantity  TotalExciseTax  freightCost  \
# 0           50000.0                 100          2000.0        500.0
#
#    GrossProfit  ProfitMargin  StockTurnover  SalesToPurchaseRatio
# 0       5000.0          10.0            5.0                   1.1

# %%
# table has been created but it has no data, to insert apply to_sql method
final_table.to_sql("df", engine, if_exists = 'replace', index = False)
# Out:
# 692

# %%
final_table.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPuhchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalExciseTax           178
# freightCost                0
# GrossProfit              178
# ProfitMargin             178
# StockTurnover            178
# SalesToPurchaseRatio     178
# dtype: int64

# %%
import psycopg2
import pandas as pd
import logging

logging.basicConfig(
    filename = "logs/get_vendor_summary.log",
    level = logging.DEBUG,
    format = "%(asctime)s - %(levelname)s - %(message)s",
    filemode = "a"
)
engine = create_engine('postgresql://postgres:password@localhost/inventory')
    
def create_vendor_summary(engine):
    ''' This function will merge differnt tables to get the overall vendor summary and adding new columns in the vendor data'''
    
    vendor_sales_summary = pd.read_sql(""" with freight_summary as (
  select
     "VendorNumber", 
     sum("Freight") as "freightCost" 
     from vendor_invoice 
     group by "VendorNumber"
),
Purchase_summary as (
 select 
     p."VendorNumber", 
     p."VendorName", 
     p."Brand", 
     pp."Description",
     p."PurchasePrice", 
     pp."Volume",
     pp."Price" as "ActualPrice",
     sum(p."Quantity") as "TotalPurchaseQuantity", 
     sum(p."Dollars") as "TotalPuhchaseDollars" 
     from purchases p
     join purchase_prices pp 
     on p."Brand" = pp."Brand" 
     where p."PurchasePrice" > 0
     group by
       p."VendorNumber", 
       p."VendorName", 
       p."Brand",
       pp."Description",
       p."PurchasePrice", 
       pp."Volume",
       pp."Price"  
),
sales_summary as (
  select 
     "VendorNo", 
     "Brand", 
   sum("SalesDollars") as "TotalSalesDollars",
   sum("SalesPrice") as "TotalSalesPrice",
   sum("SalesQuantity") as "TotalSalesQuantity",
   sum("ExciseTax") as "TotalExciseTax"
    from sales
   group by 
   "VendorNo", 
   "Brand"
)

select 
     ps."VendorNumber",
     ps."VendorName",
     ps."Brand",
     ps."Description",
     ps."PurchasePrice",
     ps."ActualPrice",
     ps."Volume",
     ps."TotalPurchaseQuantity",
     ps."TotalPuhchaseDollars",
     ss."TotalSalesQuantity",
     ss."TotalSalesDollars",
     ss."TotalExciseTax",
     fs."freightCost" 
From Purchase_summary ps
left join sales_summary ss
     on ps."VendorNumber" = ss."VendorNo"
     and ps."Brand" = ss."Brand"
left join freight_summary fs
     on ps."VendorNumber" = fs."VendorNumber"
order by ps."TotalPuhchaseDollars" desc """, engine)
    

    return vendor_sales_summary

def clean_data(df):
    '''this function will clean the data'''
    
    # chnging the dtype from obj to float
    df['Volume'] = df["Volume"].astype('float')  

   # removing spaces from categorical columns
    df['VendorName'] = df['VendorName'].str.strip()

   # creating new columns for better analysis
    df['GrossProfit'] = df['TotalSalesDollars'] - df['TotalPuhchaseDollars']
    df['ProfitMargin'] = (df['GrossProfit'] / df['TotalSalesDollars'])*100
    df['StockTurnover'] = df['TotalSalesQuantity'] / df['TotalPurchaseQuantity']
    df['SalesToPurchaseRatio'] = df['TotalSalesDollars'] / df['TotalPuhchaseDollars']

    return df

if __name__ == "__main__":
    
    logging.info("Creating Vendor Summary Table...")
    summary_df = create_vendor_summary(engine)
    logging.info(summary_df.head())
    
    logging.info("Cleaning data begins...")
    clean_df = clean_data(summary_df)
    logging.info(clean_df.head())
    
    logging.info("Ingesting data...")
    ingest_db(clean_df, 'final_table', engine)
    logging.info('Completed')

# %%
final_table.count()
# Out:
# VendorNumber             10692
# VendorName               10692
# Brand                    10692
# Description              10692
# PurchasePrice            10692
# ActualPrice              10692
# Volume                   10692
# TotalPurchaseQuantity    10692
# TotalPuhchaseDollars     10692
# TotalSalesQuantity       10514
# TotalSalesDollars        10514
# TotalExciseTax           10514
# freightCost              10692
# GrossProfit              10514
# ProfitMargin             10514
# StockTurnover            10514
# SalesToPurchaseRatio     10514
# dtype: int64
